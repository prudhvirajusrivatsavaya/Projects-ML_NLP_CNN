# %%
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV

# %%
tips=sns.load_dataset('tips')

# %%
smoker=LabelEncoder()
smoker.fit(tips['smoker'])
tips['smoker']=smoker.transform(tips['smoker'])
day=LabelEncoder()
smoker.fit(tips['day'])
tips['day']=smoker.transform(tips['day'])
time=LabelEncoder()
smoker.fit(tips['time'])
tips['time']=smoker.transform(tips['time'])
sex=LabelEncoder()
smoker.fit(tips['sex'])
tips['sex']=smoker.transform(tips['sex'])

# %%
Y=tips['smoker']
tips.drop('smoker',axis=1,inplace=True)

# %%
tips.head()
# Out:
#    total_bill   tip  sex  day  time  size
# 0       16.99  1.01    0    2     0     2
# 1       10.34  1.66    1    2     0     3
# 2       21.01  3.50    1    2     0     3
# 3       23.68  3.31    1    2     0     2
# 4       24.59  3.61    0    2     0     4

# %%
parameters={'C':[0.001,0.01,0.1,10,100,1000]}
svc_clf=SVC(kernel='linear',probability=True)
gs_svc=GridSearchCV(svc_clf,parameters)
gs_svc.fit(tips,Y)
print('Best Estimator: {}'.format(gs_svc.best_estimator_))
# Out:
# Best Estimator: SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
svc_clf=SVC(C=10,kernel='linear',probability=True)
svc_clf.fit(tips,Y)
svc_clf.predict_proba(tips)
# Out:
# array([[0.61564287, 0.38435713],
#        [0.77787298, 0.22212702],
#        [0.72033767, 0.27966233],
#        [0.62044361, 0.37955639],
#        [0.73127221, 0.26872779],
#        [0.76414419, 0.23585581],
#        [0.74441965, 0.25558035],
#        [0.71456945, 0.28543055],
#        [0.68157163, 0.31842837],
#        [0.71464909, 0.28535091],
#        [0.72381507, 0.27618493],
#        [0.65280689, 0.34719311],
#        [0.6645749 , 0.3354251 ],
#        [0.78802649, 0.21197351],
#        [0.69180436, 0.30819564],
#        [0.65807336, 0.34192664],
#        [0.76346001, 0.23653999],
#        [0.7682596 , 0.2317404 ],
#        [0.74240573, 0.25759427],
#        [0.60923714, 0.39076286],
#        [0.58956723, 0.41043277],
#        [0.5       , 0.5       ],
#        [0.54342644, 0.45657356],
#        [0.57885646, 0.42114354],
#        [0.54224285, 0.45775715],
#        [0.68331668, 0.31668332],
#        [0.58565994, 0.41434006],
#        [0.59349368, 0.40650632],
# ...

# %%
svc_clf.class_weight_
# Out:
# array([1., 1.])

# %%
svc_clf.classes_
# Out:
# array([0, 1], dtype=int64)

# %%
svc_clf.coef_
# Out:
# array([[ 0.07453227, -0.17516372, -0.12809058, -0.76821696,  0.72568399,
#         -0.46025361]])

# %%
from sklearn.calibration import CalibratedClassifierCV

# %%
CC_svc=CalibratedClassifierCV(svc_clf,method='sigmoid')
CC_svc.fit(tips,Y)
CC_svc.predict_proba(tips)
# Out:
# array([[0.68958165, 0.31041835],
#        [0.80740063, 0.19259937],
#        [0.74781123, 0.25218877],
#        [0.62586389, 0.37413611],
#        [0.77211735, 0.22788265],
#        [0.76613245, 0.23386755],
#        [0.79224295, 0.20775705],
#        [0.73592129, 0.26407871],
#        [0.73508203, 0.26491797],
#        [0.75407729, 0.24592271],
#        [0.78065022, 0.21934978],
#        [0.6534629 , 0.3465371 ],
#        [0.72325054, 0.27674946],
#        [0.79682141, 0.20317859],
#        [0.75854415, 0.24145585],
#        [0.67728565, 0.32271435],
#        [0.81710772, 0.18289228],
#        [0.78479257, 0.21520743],
#        [0.78918168, 0.21081832],
#        [0.61835825, 0.38164175],
#        [0.59341107, 0.40658893],
#        [0.49636727, 0.50363273],
#        [0.57581998, 0.42418002],
#        [0.47181575, 0.52818425],
#        [0.52028041, 0.47971959],
#        [0.7277807 , 0.2722193 ],
#        [0.6185765 , 0.3814235 ],
#        [0.63275237, 0.36724763],
# ...

# %%
svc_poly=SVC(kernel='poly',degree=2,gamma=0.01,probability=True)

# %%
from sklearn.ensemble import GradientBoostingClassifier
GBDT_C=GradientBoostingClassifier()
GBDT_C.fit(tips,Y)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)
