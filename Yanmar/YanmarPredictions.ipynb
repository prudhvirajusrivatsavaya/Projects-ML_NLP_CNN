# %%
import numpy
import pandas
import matplotlib.pyplot as plt

from sklearn.cross_validation import train_test_split
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
RMLEng468Data = pandas.read_csv('D:/Projects/MicroTec/Yanmar-Analysis/Datasets/PredictiveMaintenance/rml468Data.csv',sep=',')

# %%
datasetTrain = RMLEng468Data.values
X = datasetTrain[:,0:5]
Y = datasetTrain[:,5]
validationSize = 0.2
seed = 7
XTrain,XTest,YTrain,YTest = train_test_split(X,Y,test_size=validationSize,random_state=seed)

testModel = RandomForestRegressor()
testModel.fit(XTrain,YTrain)
testPredictions = testModel.predict(XTest)
print 'MSE: %.2f'%mean_squared_error(YTest,testPredictions)
print 'R-squared: %.2f'%r2_score(YTest,testPredictions)
# Out:
# MSE: 172876.13
# R-squared: 1.00

# %%
#Predictions on eng 468 2016 year dataset
#Testing for 2016
year2016Dataset = pandas.read_csv('D:/Projects/MicroTec/Yanmar-Analysis/Datasets/Year2016.csv',sep=',')
unindexed468year2016 = year2016Dataset.query('P_EngineSerial == 468')
year2016Dataset['P_SamplingDateTime'] = pandas.to_datetime(year2016Dataset['P_SamplingDateTime'],format='%Y-%m-%d %H:%M')
year2016Dataset = year2016Dataset.set_index('P_SamplingDateTime')
engOpDataset = year2016Dataset.query('A_Temp_ExGasAvg > 0')

rollingMeanSize = 2500
maintenanceEng468Df2016 = pandas.DataFrame(pandas.rolling_mean(engOpDataset.query('P_EngineSerial == 468')['A_Temp_ExGasAvg'],rollingMeanSize))

for feature in ['A_Temp_ExGasTCOut','A_Press_BstAir','A_AnalogData_float1','A_AnalogData_int4']:
    maintenanceEng468Df2016[feature] = pandas.DataFrame(pandas.rolling_mean(unindexed468year2016.query('A_Temp_ExGasAvg > 0')[feature],rollingMeanSize),index=maintenanceEng468Df2016.index)
for feature in ['A_Temp_ExGasTCOut','A_Press_BstAir','A_AnalogData_float1','A_AnalogData_int4']:
    maintenanceEng468Df2016[feature] = pandas.DataFrame(pandas.rolling_mean(engOpDataset.query('P_EngineSerial == 468')[feature],rollingMeanSize))

maintenanceEng468Df2016 = maintenanceEng468Df2016[numpy.isfinite(maintenanceEng468Df2016['A_Temp_ExGasAvg'])]

dataset468RM2016 = maintenanceEng468Df2016.values
eng468year2016X = dataset468RM2016[:,0:5]
# Out:
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:10: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=2500,center=False).mean()
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:13: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=2500,center=False).mean()
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:15: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=2500,center=False).mean()

# %%
maintenanceEng468Df2016
# Out:
#                      A_Temp_ExGasAvg  A_Temp_ExGasTCOut  A_Press_BstAir  \
# P_SamplingDateTime
# 2016-01-08 00:08:02         350.0832           312.6044        0.142988
# 2016-01-08 00:09:02         350.1732           312.7096        0.143044
# 2016-01-08 00:10:01         350.2220           312.7932        0.143096
# 2016-01-08 00:11:01         350.2416           312.8560        0.143144
# 2016-01-08 00:12:01         350.2524           312.9056        0.143192
# 2016-01-08 00:13:01         350.2604           312.9468        0.143238
# 2016-01-08 00:14:01         350.2680           312.9820        0.143286
# 2016-01-08 00:15:01         350.2768           313.0128        0.143333
# 2016-01-08 00:16:00         350.2864           313.0404        0.143379
# 2016-01-08 00:17:00         350.2972           313.0656        0.143426
# 2016-01-08 00:18:00         350.3156           313.0912        0.143476
# 2016-01-08 00:19:00         350.3404           313.1180        0.143526
# 2016-01-08 00:20:00         350.3660           313.1452        0.143574
# 2016-01-08 00:21:00         350.3912           313.1720        0.143623
# 2016-01-08 00:22:00         350.4164           313.1984        0.143672
# 2016-01-08 00:22:59         350.4412           313.2236        0.143721
# 2016-01-08 00:23:59         350.4608           313.2460        0.143768
# 2016-01-08 00:24:59         350.4796           313.2668        0.143815
# 2016-12-22 11:46:04            185.96360          1449.5360
# 2016-12-22 11:47:04            185.90340          1449.2004
# 2016-12-22 11:48:04            185.84420          1448.8556
# 2016-12-22 11:49:04            185.78180          1448.4824
# 2016-12-22 11:50:04            185.69800          1448.0752
#
# [170035 rows x 5 columns]

# %%
RMLEng469Data = pandas.read_csv('D:/Projects/MicroTec/Yanmar-Analysis/Datasets/PredictiveMaintenance/rml469Data.csv',sep=',')
datasetTrain = RMLEng469Data.values
X = datasetTrain[:,0:5]
Y = datasetTrain[:,5]
validationSize = 0.2
seed = 7
XTrain,XTest,YTrain,YTest = train_test_split(X,Y,test_size=validationSize,random_state=seed)

testModel = RandomForestRegressor()
testModel.fit(XTrain,YTrain)
testPredictions = testModel.predict(XTest)
print 'MSE: %.2f'%mean_squared_error(YTest,testPredictions)
print 'R-squared: %.2f'%r2_score(YTest,testPredictions)
# Out:
# MSE: 618574.52
# R-squared: 1.00

# %%
eng469predictions = testModel.predict(eng469year2016X)
eng469predictionsDf = maintenanceEng469Df2016
eng469predictionsDf['predictions'] = pandas.DataFrame(eng469predictions,index=maintenanceEng469Df2016.index)
plt.figure(figsize=(20,7))
plt.plot(eng469predictionsDf['predictions'])
plt.show()

# %%
eng470predictions = testModel.predict(eng470year2016X)
eng470predictionsDf = maintenanceEng470Df2016
eng470predictionsDf['predictions'] = pandas.DataFrame(eng470predictions,index=maintenanceEng470Df2016.index)
plt.figure(figsize=(20,7))
plt.plot(eng470predictionsDf['predictions'])
plt.show()

# %%
#Predictions rolling mean
plt.figure(figsize=(20,7))
plt.title('Engine 468 predictions')
plt.plot(pandas.DataFrame(pandas.rolling_mean(eng468predictionsDf['predictions'],5000),index=maintenanceEng468Df2016.index))
plt.ylabel('minutes')
plt.xlabel('ts')
plt.show()
# Out:
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=5000,center=False).mean()

# %%
plt.figure(figsize=(20,7))
plt.title('Engine 469 predictions')
plt.plot(pandas.DataFrame(pandas.rolling_mean(eng469predictionsDf['predictions'],5000),index=maintenanceEng469Df2016.index))
plt.ylabel('minutes')
plt.xlabel('ts')
plt.show()
# Out:
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=5000,center=False).mean()
#   app.launch_new_instance()

# %%
#Predictions rolling mean
plt.figure(figsize=(20,7))
plt.title('Engine 470 predictions')
plt.plot(pandas.DataFrame(pandas.rolling_mean(eng470predictionsDf['predictions'],5000),index=maintenanceEng470Df2016.index))
plt.ylabel('minutes')
plt.xlabel('ts')
plt.show()
# Out:
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=5000,center=False).mean()

# %%
year2012Data = pandas.read_csv('D:/Projects/MicroTec/Yanmar-Analysis/Datasets/Year2012.csv',sep=',')

# %%
opYear2012Data = year2012Data.query('A_Temp_ExGasAvg > 0')

# %%
print("Min,Max,Mean,Median,Q1,Q3,LIF,LOF,UIF,UOF")
for feature in ['A_Temp_ExGasAvg','A_Temp_ExGasTCOut','A_Press_BstAir','A_AnalogData_float1','A_AnalogData_int4']:
    q1 = opYear2012Data[feature].quantile(0.25)
    q3 = opYear2012Data[feature].quantile(0.75)
    iq = q3-q1
    lif = q1 - 1.5*iq
    lof = q1 - 3*iq
    uif = q3 +1.5*iq
    uof = q3 +3*iq
    median = opYear2012Data[feature].median()
    mean = opYear2012Data[feature].mean()
    min = opYear2012Data[feature].min()
    max = opYear2012Data[feature].max()    
    #print(feature,(min,max,mean,median,q1,q3,lif,lof,uif,uof))
    print(feature,(lif,lof,uif,uof))
# Out:
# Min,Max,Mean,Median,Q1,Q3,LIF,LOF,UIF,UOF
# ('A_Temp_ExGasAvg', (327.0, 300.0, 399.0, 426.0))
# ('A_Temp_ExGasTCOut', (300.5, 269.0, 384.5, 416.0))
# ('A_Press_BstAir', (-0.042499999999999996, -0.15799999999999997, 0.26549999999999996, 0.38100000000000001))
# ('A_AnalogData_float1', (37.799999999999997, -51.300000000000011, 275.40000000000003, 364.5))
# ('A_AnalogData_int4', (67.0, -926.0, 2715.0, 3708.0))

# %%
#Prediction dates for Engine 468
prediction468Data = pandas.DataFrame(pandas.rolling_mean(eng468predictionsDf['predictions'],5000))
prediction468Data.idxmin()
# Out:
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=5000,center=False).mean()
#   from ipykernel import kernelapp as app
# predictions   2016-06-06 01:25:03
# dtype: datetime64[ns]

# %%
#Prediction dates for Engine 469
prediction469Data = pandas.DataFrame(pandas.rolling_mean(eng469predictionsDf['predictions'],5000))
prediction469Data.idxmin()
# Out:
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=5000,center=False).mean()
#   from ipykernel import kernelapp as app
# predictions   2016-06-22 17:13:04
# dtype: datetime64[ns]

# %%
#Prediction dates for Engine 470
prediction470Data = pandas.DataFrame(pandas.rolling_mean(eng470predictionsDf['predictions'],5000))
prediction470Data.idxmin()
# Out:
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=5000,center=False).mean()
#   from ipykernel import kernelapp as app
# predictions   2016-07-08 16:20:01
# dtype: datetime64[ns]

# %%
#Differential graphs
diff468PredictionData = pandas.DataFrame(pandas.rolling_mean(eng468predictionsDf['predictions'],10000)).diff()
print diff468PredictionData.idxmin()
plt.figure(figsize=(20,7))
plt.title('Differential of predictions for year 468')
plt.plot(diff468PredictionData)
plt.show()
# Out:
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10000,center=False).mean()
#   from ipykernel import kernelapp as app
# predictions   2016-05-17 20:47:00
# dtype: datetime64[ns]

# %%
#Differential graphs
diff469PredictionData = pandas.DataFrame(pandas.rolling_mean(eng469predictionsDf['predictions'],10000)).diff()
print diff469PredictionData.idxmin()
plt.figure(figsize=(20,7))
plt.title('Differential of predictions for year 469')
plt.plot(diff469PredictionData)
plt.show()
# Out:
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10000,center=False).mean()
#   from ipykernel import kernelapp as app
# predictions   2016-05-18 03:23:00
# dtype: datetime64[ns]

# %%
#Differential graphs
diff470PredictionData = pandas.DataFrame(pandas.rolling_mean(eng470predictionsDf['predictions'],10000)).diff()
print diff470PredictionData.idxmin()
plt.figure(figsize=(20,7))
plt.title('Differential of predictions for year 470')
plt.plot(diff470PredictionData)
plt.show()
# Out:
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=10000,center=False).mean()
#   from ipykernel import kernelapp as app
# predictions   2016-05-23 23:38:00
# dtype: datetime64[ns]

# %%
plt.figure(figsize=(20,7))
plt.plot(pandas.DataFrame(pandas.rolling_mean(diff468PredictionData,8000)),label='468')
plt.plot(pandas.DataFrame(pandas.rolling_mean(diff469PredictionData,8000)),label='469')
plt.plot(pandas.DataFrame(pandas.rolling_mean(diff470PredictionData,8000)),label='470')
plt.legend()
plt.show()
# Out:
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=8000,center=False).mean()
#   from ipykernel import kernelapp as app
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=8000,center=False).mean()
#   app.launch_new_instance()
# C:\Program Files\Anaconda\lib\site-packages\ipykernel\__main__.py:4: FutureWarning: pd.rolling_mean is deprecated for DataFrame and will be removed in a future version, replace with
# 	DataFrame.rolling(window=8000,center=False).mean()

# %%
maintenanceEng468Df2016.to_csv('D:/Projects/MicroTec/Yanmar-Analysis/Datasets/PredictiveMaintenance/year2016Eng468RMData.csv',sep=',')
