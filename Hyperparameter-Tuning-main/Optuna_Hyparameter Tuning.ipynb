# %%
import pandas as pd
import optuna
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("heart.csv")

# %%
df = pd.get_dummies(df)
df.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
#
#    Sex_F  Sex_M  ChestPainType_ASY  ...  ChestPainType_NAP  ChestPainType_TA  \
# 0  False   True              False  ...              False             False
# 1   True  False              False  ...               True             False
# 2  False   True              False  ...              False             False
# 3   True  False               True  ...              False             False
# 4  False   True              False  ...               True             False
#
#    RestingECG_LVH  RestingECG_Normal  RestingECG_ST  ExerciseAngina_N  \
# 0           False               True          False              True
# 1           False               True          False              True
# 2           False              False           True              True
# 3           False               True          False             False
# 4           False               True          False              True
#
#    ExerciseAngina_Y  ST_Slope_Down  ST_Slope_Flat  ST_Slope_Up
# 0             False          False          False         True
# 1             False          False           True        False
# 2             False          False          False         True
# 3              True          False           True        False
# 4             False          False          False         True
#
# [5 rows x 21 columns]

# %%
import torch

class Dataset(torch.utils.data.Dataset):

    def __init__(self, df):
        self.labels = [0 if label == 0 else 1 for label in df['HeartDisease']]
        self.features = df.drop(columns=['HeartDisease'], axis=1).values.tolist()

    def classes(self):
        return self.labels

    def __len__(self):
        return len(self.labels)

    def get_batch_labels(self, idx):
        return np.array(self.labels[idx])

    def get_batch_features(self, idx):
        return np.array(self.features[idx])

    def __getitem__(self, idx):
        batch_features = self.get_batch_features(idx)
        batch_y = self.get_batch_labels(idx)

        return batch_features, batch_y

# %%
# Build neural network model
def build_model(params):
    
    in_features = 20
    
    return nn.Sequential(
    
        nn.Linear(in_features, params['n_unit']),
        nn.LeakyReLU(),
        nn.Linear(params['n_unit'], 2),
        nn.LeakyReLU()
        
    )

# %%
# Train and evaluate the accuarcy of neural network model
def train_and_evaluate(param, model):
    
    df = pd.read_csv('heart.csv')
    df = pd.get_dummies(df)
    
    train_data, val_data = train_test_split(df, test_size = 0.2, random_state = 42)
    train, val = Dataset(train_data), Dataset(val_data)

    train_dataloader = torch.utils.data.DataLoader(train, batch_size=2, shuffle=True)
    val_dataloader = torch.utils.data.DataLoader(val, batch_size=2)

    use_cuda = torch.cuda.is_available()
    device = torch.device("cuda" if use_cuda else "cpu")

    criterion = nn.CrossEntropyLoss()
    optimizer = getattr(optim, param['optimizer'])(model.parameters(), lr= param['learning_rate'])

    if use_cuda:

            model = model.cuda()
            criterion = criterion.cuda()

    for epoch_num in range(EPOCHS):

            total_acc_train = 0
            total_loss_train = 0

            for train_input, train_label in train_dataloader:

                train_label = train_label.to(device)
                train_input = train_input.to(device)

                output = model( .float())
                
                batch_loss = criterion(output, train_label.long())
                total_loss_train += batch_loss.item()
                
                acc = (output.argmax(dim=1) == train_label).sum().item()
                total_acc_train += acc

                model.zero_grad()
                batch_loss.backward()
                optimizer.step()
            
            total_acc_val = 0
            total_loss_val = 0

            with torch.no_grad():

                for val_input, val_label in val_dataloader:

                    val_label = val_label.to(device)
                    val_input = val_input.to(device)

                    output = model(val_input.float())

                    batch_loss = criterion(output, val_label.long())
                    total_loss_val += batch_loss.item()
                    
                    acc = (output.argmax(dim=1) == val_label).sum().item()
                    total_acc_val += acc
            
            accuracy = total_acc_val/len(val_data)

    return accuracy

# %%
def objective(trial):

    params = {
              'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
              'optimizer': trial.suggest_categorical("optimizer", ["Adam", "RMSprop", "SGD"]),
              'n_unit': trial.suggest_int("n_unit", 4, 18)
              }
    
    model = build_model(params)
    
    accuracy = train_and_evaluate(params, model)

    return accuracy

# %%
import optuna

study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler())
# Out:
# [I 2023-10-12 20:03:46,373] A new study created in memory with name: no-name-4687dec0-f1aa-49b8-839a-879b694d41d8

# %%
import optuna
EPOCHS = 30
study = optuna.create_study(direction="maximize", sampler=optuna.samplers.TPESampler())
study.optimize(objective, n_trials=30)
# Out:
# [I 2023-10-12 20:03:47,398] A new study created in memory with name: no-name-6fa51ffe-55f3-4cb3-af6b-f726b1f6126f
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:04:07,533] Trial 0 finished with value: 0.5978260869565217 and parameters: {'learning_rate': 0.0015316705940706028, 'optimizer': 'SGD', 'n_unit': 4}. Best is trial 0 with value: 0.5978260869565217.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:04:29,864] Trial 1 finished with value: 0.6195652173913043 and parameters: {'learning_rate': 0.00023842415548633796, 'optimizer': 'SGD', 'n_unit': 17}. Best is trial 1 with value: 0.6195652173913043.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:04:47,971] Trial 2 finished with value: 0.5434782608695652 and parameters: {'learning_rate': 1.789653452388073e-05, 'optimizer': 'SGD', 'n_unit': 4}. Best is trial 1 with value: 0.6195652173913043.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:05:10,408] Trial 3 finished with value: 0.8315217391304348 and parameters: {'learning_rate': 0.07271550505193544, 'optimizer': 'RMSprop', 'n_unit': 16}. Best is trial 3 with value: 0.8315217391304348.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:05:36,232] Trial 4 finished with value: 0.8097826086956522 and parameters: {'learning_rate': 0.001171937532367528, 'optimizer': 'Adam', 'n_unit': 14}. Best is trial 3 with value: 0.8315217391304348.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:06:01,567] Trial 5 finished with value: 0.7010869565217391 and parameters: {'learning_rate': 0.026754835333604815, 'optimizer': 'Adam', 'n_unit': 8}. Best is trial 3 with value: 0.8315217391304348.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:06:20,366] Trial 6 finished with value: 0.625 and parameters: {'learning_rate': 0.00274095855717241, 'optimizer': 'SGD', 'n_unit': 15}. Best is trial 3 with value: 0.8315217391304348.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:06:48,102] Trial 7 finished with value: 0.7771739130434783 and parameters: {'learning_rate': 6.541119855987884e-05, 'optimizer': 'Adam', 'n_unit': 13}. Best is trial 3 with value: 0.8315217391304348.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:07:06,829] Trial 8 finished with value: 0.6086956521739131 and parameters: {'learning_rate': 0.003819104867549511, 'optimizer': 'SGD', 'n_unit': 6}. Best is trial 3 with value: 0.8315217391304348.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:07:32,026] Trial 9 finished with value: 0.8641304347826086 and parameters: {'learning_rate': 0.0837078220612523, 'optimizer': 'RMSprop', 'n_unit': 11}. Best is trial 9 with value: 0.8641304347826086.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:07:55,433] Trial 10 finished with value: 0.8315217391304348 and parameters: {'learning_rate': 0.013282071907967069, 'optimizer': 'RMSprop', 'n_unit': 10}. Best is trial 9 with value: 0.8641304347826086.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:08:18,507] Trial 11 finished with value: 0.5815217391304348 and parameters: {'learning_rate': 0.09905669180419772, 'optimizer': 'RMSprop', 'n_unit': 18}. Best is trial 9 with value: 0.8641304347826086.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:08:41,735] Trial 12 finished with value: 0.8315217391304348 and parameters: {'learning_rate': 0.07200196380076661, 'optimizer': 'RMSprop', 'n_unit': 11}. Best is trial 9 with value: 0.8641304347826086.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:09:05,088] Trial 13 finished with value: 0.8641304347826086 and parameters: {'learning_rate': 0.012786357418505909, 'optimizer': 'RMSprop', 'n_unit': 9}. Best is trial 9 with value: 0.8641304347826086.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:09:28,370] Trial 14 finished with value: 0.875 and parameters: {'learning_rate': 0.01102735677989081, 'optimizer': 'RMSprop', 'n_unit': 9}. Best is trial 14 with value: 0.875.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:09:51,409] Trial 15 finished with value: 0.8586956521739131 and parameters: {'learning_rate': 0.0067516419163243585, 'optimizer': 'RMSprop', 'n_unit': 12}. Best is trial 14 with value: 0.875.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:10:14,345] Trial 16 finished with value: 0.8260869565217391 and parameters: {'learning_rate': 0.022568422870404954, 'optimizer': 'RMSprop', 'n_unit': 7}. Best is trial 14 with value: 0.875.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:10:38,380] Trial 17 finished with value: 0.875 and parameters: {'learning_rate': 0.007355795853571759, 'optimizer': 'RMSprop', 'n_unit': 10}. Best is trial 14 with value: 0.875.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:11:01,380] Trial 18 finished with value: 0.8532608695652174 and parameters: {'learning_rate': 0.0007062052662586978, 'optimizer': 'RMSprop', 'n_unit': 6}. Best is trial 14 with value: 0.875.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:11:24,845] Trial 19 finished with value: 0.842391304347826 and parameters: {'learning_rate': 0.005577058657616589, 'optimizer': 'RMSprop', 'n_unit': 9}. Best is trial 14 with value: 0.875.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:11:51,931] Trial 20 finished with value: 0.8586956521739131 and parameters: {'learning_rate': 0.0005218743369695809, 'optimizer': 'Adam', 'n_unit': 12}. Best is trial 14 with value: 0.875.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:12:15,234] Trial 21 finished with value: 0.842391304347826 and parameters: {'learning_rate': 0.02844275102424981, 'optimizer': 'RMSprop', 'n_unit': 10}. Best is trial 14 with value: 0.875.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:12:38,529] Trial 22 finished with value: 0.8804347826086957 and parameters: {'learning_rate': 0.009315755781028076, 'optimizer': 'RMSprop', 'n_unit': 11}. Best is trial 22 with value: 0.8804347826086957.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:13:01,799] Trial 23 finished with value: 0.875 and parameters: {'learning_rate': 0.0024542923659239507, 'optimizer': 'RMSprop', 'n_unit': 9}. Best is trial 22 with value: 0.8804347826086957.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:13:25,114] Trial 24 finished with value: 0.7336956521739131 and parameters: {'learning_rate': 0.008006882344751231, 'optimizer': 'RMSprop', 'n_unit': 13}. Best is trial 22 with value: 0.8804347826086957.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:13:48,073] Trial 25 finished with value: 0.8260869565217391 and parameters: {'learning_rate': 0.0038966675351982775, 'optimizer': 'RMSprop', 'n_unit': 7}. Best is trial 22 with value: 0.8804347826086957.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:14:15,172] Trial 26 finished with value: 0.8532608695652174 and parameters: {'learning_rate': 0.008295699743723468, 'optimizer': 'RMSprop', 'n_unit': 10}. Best is trial 22 with value: 0.8804347826086957.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:14:38,642] Trial 27 finished with value: 0.842391304347826 and parameters: {'learning_rate': 0.0021065754162905696, 'optimizer': 'RMSprop', 'n_unit': 12}. Best is trial 22 with value: 0.8804347826086957.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:15:06,365] Trial 28 finished with value: 0.8478260869565217 and parameters: {'learning_rate': 0.014661157077646307, 'optimizer': 'Adam', 'n_unit': 8}. Best is trial 22 with value: 0.8804347826086957.
# C:\Users\User\AppData\Local\Temp\ipykernel_12888\1782196025.py:4: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 1e-5, 1e-1),
# [I 2023-10-12 20:15:29,482] Trial 29 finished with value: 0.8478260869565217 and parameters: {'learning_rate': 0.0015141967214755674, 'optimizer': 'RMSprop', 'n_unit': 4}. Best is trial 22 with value: 0.8804347826086957.

# %%
best_trial = study.best_trial

for key, value in best_trial.params.items():
    print("{}: {}".format(key, value))
# Out:
# learning_rate: 0.009315755781028076
# optimizer: RMSprop
# n_unit: 11
